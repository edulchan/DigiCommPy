# %% [markdown]
# <a href="https://colab.research.google.com/github/edulchan/DigiCommPy/blob/main/Signals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/My Drive/')

# %%
sys.path.append('/content/gdrive/My Drive/DigiCommPy')

# %%
from DigiCommPy.chapter_1.demo_scripts import sine_wave_demo

# %%
sine_wave_demo()
